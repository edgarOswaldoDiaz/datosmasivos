# %% [markdown]
# #####  Verificar la versión de Python Pandas instalada

# %%
import pandas as pd
print(pd.__version__)
pd.show_versions()
# Out:
# 1.4.1
#
# INSTALLED VERSIONS
# ------------------
# commit           : 06d230151e6f18fdb8139d09abf539867a8cd481
# python           : 3.9.10.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.10.76-linuxkit
# Version          : #1 SMP Mon Nov 8 10:21:19 UTC 2021
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.4.1
# numpy            : 1.21.5
# pytz             : 2021.3
# dateutil         : 2.8.2
# pip              : 22.0.3
# setuptools       : 59.8.0
# Cython           : 0.29.28
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.0.3
# IPython          : 8.0.1
# ...
