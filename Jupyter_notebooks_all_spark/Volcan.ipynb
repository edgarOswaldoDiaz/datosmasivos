# %% [markdown]
# #### Gráfica en 3d para relieve del Volcán Maunga Whau, Auckland, NZ

# %%
persp(x = 10*(1:nrow(volcano)), y=10*(1:ncol(volcano)), z=3*volcano, 
      theta = 130, phi = 30, col = "gray", scale = FALSE,
      ltheta = -120, shade = 0.75, border = NA, box = FALSE, main="E S T R U C T U R A")
# Out:
# Plot with title “E S T R U C T U R A”
