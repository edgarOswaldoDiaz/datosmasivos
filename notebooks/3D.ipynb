# %% [markdown]
# ##### Gráfica en 3d para un rango de datos muestra

# %%
fun <- function(x, y)   sin(x^2 + y^2)
x <- seq(from=-2, to=2, length.out=25)
y <- seq(from=-2, to=2, length.out=25)
z <- outer(x, y, fun)
par(mfrow=c(2, 2), mar=c(1, 1, 2, 1))
persp(x, y, z, zlim=c(-1, 1.5), theta=45, phi=30, col='red',
      main='Muestra (A)')
persp(x, y, z, zlim=c(-1, 1.5), theta=60, phi=50, col='lightblue',
      main='Muestra (B)')
# Out:
# Plot with title “Muestra (B)”
